# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Rent_Data1.txt")
# Out:
# C:\Users\61478\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Year Quarter LGA (Local Government Areas) Dwelling Types Bedroom Numbers  \
# 0  2019  Second                       Albury          Total           Total
# 1  2019  Second                       Albury          Total       Bedsitter
# 2  2019  Second                       Albury          Total       1 Bedroom
# 3  2019  Second                       Albury          Total   Not Specified
# 4  2019  Second                       Albury          Total      2 Bedrooms
#
#   First Quartile Weekly Rent for New Bonds\n$  \
# 0                                         220
# 1                                           -
# 2                                         165
# 3                                           -
# 4                                         190
#
#   Median Weekly Rent for New Bonds\n$  \
# 0                                 275
# 1                                   -
# 2                                 178
# 3                                   -
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42449 entries, 0 to 42448
# Data columns (total 17 columns):
# Year                                          42449 non-null int64
# Quarter                                       42449 non-null object
# LGA (Local Government Areas)                  42449 non-null object
# Dwelling Types                                42449 non-null object
# Bedroom Numbers                               42446 non-null object
# First Quartile Weekly Rent for New Bonds
# $    42446 non-null object
# Median Weekly Rent for New Bonds
# $            42446 non-null object
# Third Quartile Weekly Rent for New Bonds
# $    42446 non-null object
# New Bonds Lodged
# No.                          42446 non-null object
# Total Bonds Held
# No.                          42445 non-null object
# Quarterly change in Median Weekly Rent        42443 non-null object
# Annual change in Median Weekly Rent           42432 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Year                                               0
# Quarter                                            0
# LGA (Local Government Areas)                       0
# Dwelling Types                                     0
# Bedroom Numbers                                    0
# First Quartile Weekly Rent for New Bonds\n$        0
# Median Weekly Rent for New Bonds\n$                0
# Third Quartile Weekly Rent for New Bonds\n$        0
# New Bonds Lodged\nNo.                              0
# Total Bonds Held\nNo.                              0
# Quarterly change in Median Weekly Rent             0
# Annual change in Median Weekly Rent                0
# Quarterly change in New Bonds Lodged               0
# Annual change in New Bonds Lodged                  0
# Unnamed: 14                                    13915
# Unnamed: 15                                    34491
# Unnamed: 16                                    34491
# dtype: int64

# %%
df= df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Year                                               0
# Quarter                                            0
# LGA (Local Government Areas)                       0
# Dwelling Types                                     0
# Bedroom Numbers                                    0
# First Quartile Weekly Rent for New Bonds\n$        0
# Median Weekly Rent for New Bonds\n$                0
# Third Quartile Weekly Rent for New Bonds\n$        0
# New Bonds Lodged\nNo.                              0
# Total Bonds Held\nNo.                              0
# Quarterly change in Median Weekly Rent             0
# Annual change in Median Weekly Rent                0
# Quarterly change in New Bonds Lodged               0
# Annual change in New Bonds Lodged                  0
# Unnamed: 14                                    13915
# Unnamed: 15                                    34491
# Unnamed: 16                                    34491
# dtype: int64

# %%
df.head()
# Out:
#    Year Quarter LGA (Local Government Areas) Dwelling Types Bedroom Numbers  \
# 0  2019  Second                       Albury          Total           Total
# 1  2019  Second                       Albury          Total       Bedsitter
# 2  2019  Second                       Albury          Total       1 Bedroom
# 3  2019  Second                       Albury          Total   Not Specified
# 4  2019  Second                       Albury          Total      2 Bedrooms
#
#   First Quartile Weekly Rent for New Bonds\n$  \
# 0                                         220
# 1                                           -
# 2                                         165
# 3                                           -
# 4                                         190
#
#   Median Weekly Rent for New Bonds\n$  \
# 0                                 275
# 1                                   -
# 2                                 178
# 3                                   -
# ...

# %%
df.head()
# Out:
#    Year Quarter LGA (Local Government Areas) Dwelling Types Bedroom Numbers  \
# 0  2019  Second                       Albury          Total           Total
# 1  2019  Second                       Albury          Total       Bedsitter
# 2  2019  Second                       Albury          Total       1 Bedroom
# 3  2019  Second                       Albury          Total   Not Specified
# 4  2019  Second                       Albury          Total      2 Bedrooms
#
#   First Quartile Weekly Rent for New Bonds\n$  \
# 0                                         220
# 1                                           -
# 2                                         165
# 3                                           -
# 4                                         190
#
#   Median Weekly Rent for New Bonds\n$  \
# 0                                 275
# 1                                   -
# 2                                 178
# 3                                   -
# ...

# %%
import seaborn as sns
x=df.iloc[:,5:6]
print(x)
y=df.iloc[:,2]
# Out:
#       First Quartile Weekly Rent for New Bonds\n$
# 0                                             220
# 1                                               -
# 2                                             165
# 3                                               -
# 4                                             190
# 5                                             280
# 6                                             360
# 7                                             275
# 8                                               -
# 9                                               -
# 10                                              -
# 11                                            213
# 12                                            280
# 13                                            364
# 14                                              -
# 15                                              -
# 16                                              -
# 17                                              -
# ...

# %%
print(y)
# Out:
# 0                Albury
# 1                Albury
# 2                Albury
# 3                Albury
# 4                Albury
# 5                Albury
# 6                Albury
# 7                Albury
# 8                Albury
# 9                Albury
# 10               Albury
# 11               Albury
# 12               Albury
# 13               Albury
# 14               Albury
# 15               Albury
# 16               Albury
# 17               Albury
# 18               Albury
# 19               Albury
# 20               Albury
# 21               Albury
# 22               Albury
# 23               Albury
# 24               Albury
# 25               Albury
# 26               Albury
# 27               Albury
# 28               Albury
# 29               Albury
#               ...
# 42419           Penrith
# 42420         Pittwater
# 42421        Sutherland
# 42422         Warringah
# 42423       Wollondilly
# 42424             Wyong
# 42425          Cessnock
# ...

# %%
list = ['Unnamed: 14','Unnamed: 15','Unnamed: 16']
x= df.drop(list,axis = 1 )

# %%
print(x)
# Out:
#        Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 0      2019  Second                       Albury          Total
# 1      2019  Second                       Albury          Total
# 2      2019  Second                       Albury          Total
# 3      2019  Second                       Albury          Total
# 4      2019  Second                       Albury          Total
# 5      2019  Second                       Albury          Total
# 6      2019  Second                       Albury          Total
# 7      2019  Second                       Albury          House
# 8      2019  Second                       Albury          House
# 9      2019  Second                       Albury          House
# 10     2019  Second                       Albury          House
# 11     2019  Second                       Albury          House
# 12     2019  Second                       Albury          House
# 13     2019  Second                       Albury          House
# ...

# %%
x.columns
# Out:
# Index(['Year', 'Quarter', 'LGA (Local Government Areas)', 'Dwelling Types',
#        'Bedroom Numbers', 'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
x.tail()
# Out:
#        Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 42444  2015   First                     Maitland          Total
# 42445  2015   First                    Newcastle          Total
# 42446  2015   First                Port Stephens          Total
# 42447  2015   First                 Shellharbour          Total
# 42448  2015   First                   Wollongong          Total
#
#       Bedroom Numbers First Quartile Weekly Rent for New Bonds\n$  \
# 42444           Total                                           -
# 42445           Total                                           -
# 42446           Total                                           -
# 42447           Total                                           -
# 42448           Total                                           -
#
#       Median Weekly Rent for New Bonds\n$  \
# 42444                                   -
# 42445                                   -
# 42446                                   -
# ...

# %%
import numpy as np
x.replace(to_replace ="-", 
                 value=np.nan)
# Out:
#        Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 0      2019  Second                       Albury          Total
# 1      2019  Second                       Albury          Total
# 2      2019  Second                       Albury          Total
# 3      2019  Second                       Albury          Total
# 4      2019  Second                       Albury          Total
# 5      2019  Second                       Albury          Total
# 6      2019  Second                       Albury          Total
# 7      2019  Second                       Albury          House
# 8      2019  Second                       Albury          House
# 9      2019  Second                       Albury          House
# 10     2019  Second                       Albury          House
# 11     2019  Second                       Albury          House
# 12     2019  Second                       Albury          House
# 13     2019  Second                       Albury          House
# ...

# %%
x.replace(to_replace = np.nan, value =159) 
x.head()
# Out:
#    Year Quarter LGA (Local Government Areas) Dwelling Types Bedroom Numbers  \
# 0  2019  Second                       Albury          Total           Total
# 1  2019  Second                       Albury          Total       Bedsitter
# 2  2019  Second                       Albury          Total       1 Bedroom
# 3  2019  Second                       Albury          Total   Not Specified
# 4  2019  Second                       Albury          Total      2 Bedrooms
#
#   First Quartile Weekly Rent for New Bonds\n$  \
# 0                                         220
# 1                                           -
# 2                                         165
# 3                                           -
# 4                                         190
#
#   Median Weekly Rent for New Bonds\n$  \
# 0                                 275
# 1                                   -
# 2                                 178
# 3                                   -
# ...

# %%
x[["First Quartile Weekly Rent for New Bonds\n$"]].mean(axis=1)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 42419   NaN
# 42420   NaN
# 42421   NaN
# 42422   NaN
# 42423   NaN
# 42424   NaN
# 42425   NaN
# 42426   NaN
# 42427   NaN
# 42428   NaN
# 42429   NaN
# 42430   NaN
# 42431   NaN
# 42432   NaN
# 42433   NaN
# 42434   NaN
# 42435   NaN
# 42436   NaN
# 42437   NaN
# 42438   NaN
# 42439   NaN
# 42440   NaN
# 42441   NaN
# 42442   NaN
# 42443   NaN
# 42444   NaN
# 42445   NaN
# 42446   NaN
# 42447   NaN
# 42448   NaN
# Length: 42449, dtype: float64

# %%
x['a']=x["First Quartile Weekly Rent for New Bonds\n$"] +x["Median Weekly Rent for New Bonds\n$"] +x["Third Quartile Weekly Rent for New Bonds\n$"]

# %%
print(x['a'])
# Out:
# 0        220275340
# 1              ---
# 2        165178200
# 3              ---
# 4        190235265
# 5        280310348
# 6        360400430
# 7        275320370
# 8              ---
# 9              ---
# 10             ---
# 11       213250279
# 12       280313350
# 13       364400430
# 14             ---
# 15             ---
# 16             ---
# 17             ---
# 18             ---
# 19             ---
# 20             ---
# 21       270305350
# 22             ---
# 23             ---
# 24             ---
# 25       244278303
# 26       299340350
# 27             ---
# 28       180210255
# 29             ---
#            ...
# 42419          ---
# 42420          ---
# 42421          ---
# 42422          ---
# 42423          ---
# 42424          ---
# 42425          ---
# 42426          ---
# 42427          ---
# 42428          ---
# 42429          ---
# 42430          ---
# 42431          ---
# 42432          ---
# 42433          ---
# 42434          ---
# ...
