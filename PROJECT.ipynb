# %%
import pandas as pd

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("Rent_Data1.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c252004fd360> in <module>
# ----> 1 df=pd.read_csv("Rent_Data1.txt")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df= df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-629914d6d1c7> in <module>
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
x=df.iloc[:,5:6]
print(x)
y=df.iloc[:,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-702c50e6441a> in <module>
#       1 import seaborn as sns
# ----> 2 x=df.iloc[:,5:6]
#       3 print(x)
#       4 y=df.iloc[:,2]
#
# NameError: name 'df' is not defined

# %%
print(y)

# %%
pearsoncorr = df.corr(method='pearson')
pearsoncorr

# %%
list = ['Unnamed: 14','Unnamed: 15','Unnamed: 16']
x= df.drop(list,axis = 1 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4bf766944472> in <module>
#       1 list = ['Unnamed: 14','Unnamed: 15','Unnamed: 16']
# ----> 2 x= df.drop(list,axis = 1 )
#
# NameError: name 'df' is not defined

# %%
print(x)

# %%
x.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-70628e5d6ae8> in <module>
# ----> 1 x.columns
#
# NameError: name 'x' is not defined

# %%
x['Dwelling Types']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f0c9c22aadb6> in <module>
# ----> 1 x['Dwelling Types']
#
# NameError: name 'x' is not defined

# %%
one_hot_encoded_training_predictors = x.get_dummies(x['Quarter'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-feb6cb4360fb> in <module>
# ----> 1 one_hot_encoded_training_predictors = x.get_dummies(x['Quarter'])
#
# NameError: name 'x' is not defined

# %%
x.tail()
# Out:
#        Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 42444  2015   First                     Maitland          Total
# 42445  2015   First                    Newcastle          Total
# 42446  2015   First                Port Stephens          Total
# 42447  2015   First                 Shellharbour          Total
# 42448  2015   First                   Wollongong          Total
#
#       Bedroom Numbers First Quartile Weekly Rent for New Bonds\n$  \
# 42444           Total                                           -
# 42445           Total                                           -
# 42446           Total                                           -
# 42447           Total                                           -
# 42448           Total                                           -
#
#       Median Weekly Rent for New Bonds\n$  \
# 42444                                   -
# 42445                                   -
# 42446                                   -
# ...

# %%
x.replace(to_replace ="-", 
                 value ="0")
# Out:
#        Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 0      2019  Second                       Albury          Total
# 1      2019  Second                       Albury          Total
# 2      2019  Second                       Albury          Total
# 3      2019  Second                       Albury          Total
# 4      2019  Second                       Albury          Total
# 5      2019  Second                       Albury          Total
# 6      2019  Second                       Albury          Total
# 7      2019  Second                       Albury          House
# 8      2019  Second                       Albury          House
# 9      2019  Second                       Albury          House
# 10     2019  Second                       Albury          House
# 11     2019  Second                       Albury          House
# 12     2019  Second                       Albury          House
# 13     2019  Second                       Albury          House
# ...

# %%
pd.get_dumies(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-072afcaf5e33> in <module>
# ----> 1 pd.get_dumies(x)
#
# NameError: name 'pd' is not defined

# %%
# Out:
#          Year Quarter LGA (Local Government Areas) Dwelling Types  \
# 0      2019.0  Second                       Albury          Total
# 1      2019.0  Second                       Albury          Total
# 2      2019.0  Second                       Albury          Total
# 3      2019.0  Second                       Albury          Total
# 4      2019.0  Second                       Albury          Total
# 5      2019.0  Second                       Albury          Total
# 6      2019.0  Second                       Albury          Total
# 7      2019.0  Second                       Albury          House
# 8      2019.0  Second                       Albury          House
# 9      2019.0  Second                       Albury          House
# 10     2019.0  Second                       Albury          House
# 11     2019.0  Second                       Albury          House
# 12     2019.0  Second                       Albury          House
# ...
